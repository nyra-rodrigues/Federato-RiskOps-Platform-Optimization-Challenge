# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('1_csv/amplitude_export_chunk_1_anonymized_subchunk_0_100000.csv')

# unique values in the 'region' column
print("Unique values in 'region':")
print(df['region'].unique())

# value counts for the 'region' column
region_counts = df['region'].value_counts()
print("\nValue counts for 'region':")
print(region_counts)

# distribution of regions (bar plot)
plt.figure(figsize=(10, 6))
region_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Regions')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

#  missing values in the 'region' column
missing_values = df['region'].isnull().sum()
print(f"\nNumber of missing values in 'region': {missing_values}")

'''region_counts = df['region'].value_counts()

# Create the pie chart
plt.figure(figsize=(10, 8))
plt.pie(region_counts, labels=region_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Region Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show() '''
# Out:
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/407334427.py:4: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('1_csv/amplitude_export_chunk_1_anonymized_subchunk_0_100000.csv')
# Unique values in 'region':
# ['Georgia' 'Oregon' 'California' 'Virginia' 'Ohio' 'Illinois' 'Florida'
#  'Tennessee' 'New York' 'New Jersey' 'Michigan' 'Maharashtra'
#  'South Carolina' 'North Carolina' 'Pennsylvania' 'Missouri' 'Colorado'
#  'Arizona' 'Texas' 'Iowa' 'Connecticut' 'Alabama' 'Wisconsin' 'Maryland'
#  'Lower Silesia' 'Massachusetts' 'Indiana' 'Utah' 'Ontario'
#  'Carmarthenshire' 'Silesia' 'England' 'South Corsica' 'Mexico City'
#  'Louisiana' 'Capital Region' 'Nevada' 'Southwark']
#
# Value counts for 'region':
# region
# Tennessee          9843
# Maharashtra        7954
# South Carolina     1973
# Illinois           1949
# New York           1745
# Iowa               1684
# Georgia            1581
# Ohio               1525
# Florida            1360
# California         1223
# Virginia            859
# North Carolina      715
# Texas               711
# Lower Silesia       455
# Alabama             437
# Arizona             388
# Wisconsin           360
# Michigan            354
# Missouri            334
# Nevada              321
# Connecticut         308
# Massachusetts       252
# Colorado            192
# Ontario             188
# Indiana             135
# Pennsylvania        110
# Utah                100
# Oregon               81
# Silesia              79
# Mexico City          59
# Carmarthenshire      54
# Louisiana            34
# Maryland             30
# Southwark            22
# New Jersey           21
# South Corsica        19
# Capital Region       12
# England              10
# Name: count, dtype: int64
# Number of missing values in 'region': 0
# "region_counts = df['region'].value_counts()\n\n# Create the pie chart\nplt.figure(figsize=(10, 8))\nplt.pie(region_counts, labels=region_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)\nplt.title('Region Distribution')\nplt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.\nplt.show() "

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset (make sure the path is correct)
df = pd.read_csv('1_csv/amplitude_export_chunk_1_anonymized_subchunk_0_100000.csv')

# Clean the 'os_version' column by extracting the first part of the version number
df['os_version'] = df['os_version'].apply(lambda x: str(x).split('.')[0] if isinstance(x, str) else str(x))

# Value counts for 'os_version'
value_counts = df['os_version'].value_counts()

# Plot the distribution of 'os_version' as a bar plot
plt.figure(figsize=(10, 6))
value_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the plot
plt.title('OS Version Distribution')
plt.xlabel('OS Version')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout to avoid clipping of labels

# Show the plot
plt.show()
# Out:
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/2992871185.py:5: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('1_csv/amplitude_export_chunk_1_anonymized_subchunk_0_100000.csv')

# %%
# Check for missing values in 'platform' column
missing_values = df['platform'].isnull().sum()

# Unique values in 'platform'
unique_values = df['platform'].unique()

# Value counts for 'platform'
platform_counts = df['platform'].value_counts()

# Display the results
print(f"Missing values in 'platform': {missing_values}")
print(f"Unique values in 'platform': {unique_values}")
print("\nValue counts for 'platform':\n", platform_counts)
# Out:
# Missing values in 'platform': 0
# Unique values in 'platform': ['Web']
#
# Value counts for 'platform':
#  platform
# Web    37477
# Name: count, dtype: int64
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/2222974340.py:2: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('1_csv/amplitude_export_chunk_1_anonymized_subchunk_0_100000.csv')

# %%
# Check for missing values in 'os_name' column
missing_values = df['os_name'].isnull().sum()

# Unique values in 'os_name'
unique_values = df['os_name'].unique()

# Value counts for 'os_name'
os_name_counts = df['os_name'].value_counts()

# Display the results
print(f"Missing values in 'os_name': {missing_values}")
print(f"Unique values in 'os_name': {unique_values}")
print("\nValue counts for 'os_name':\n", os_name_counts)

# Count the occurrences of each unique value in 'os_name'
os_name_counts = df['os_name'].value_counts()

# Set the size of the plot for better spacing
plt.figure(figsize=(10, 8))

# Create the pie chart without the text labels
plt.pie(os_name_counts, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=plt.cm.Paired.colors,
        wedgeprops={'edgecolor': 'black'},  # Adds edge color to slices for better visibility
        pctdistance=0.85)  # Move the percentages inside the pie chart

# Add a legend (key box) with the 'os_name' labels and their respective counts
plt.legend(os_name_counts.index, 
           title="OS Name", 
           loc="upper left", 
           bbox_to_anchor=(1, 1),  # Position legend outside the pie chart
           fontsize=10)

# Set the title
plt.title('Distribution of OS Name')

# Display the plot
plt.show()
# Out:
# Missing values in 'os_name': 0
# Unique values in 'os_name': ['Chrome' 'Edge' 'Firefox' 'Chrome Mobile iOS' 'Mobile Safari']
#
# Value counts for 'os_name':
#  os_name
# Chrome               35184
# Edge                  2137
# Firefox                131
# Mobile Safari           13
# Chrome Mobile iOS       12
# Name: count, dtype: int64

# %%
# Assuming 'data' is your DataFrame
eda_library = df['library'].describe()

# Show the count of unique values
unique_values = df['library'].unique()

# Frequency distribution
library_counts = df['library'].value_counts()

# Check for missing values
missing_values = df['library'].isnull().sum()

# Show the results
print("Unique values in 'library':", unique_values)
print("Frequency distribution:\n", library_counts)
print("Missing values:", missing_values)
print("\nSummary Statistics:\n", eda_library)
# Out:
# Unique values in 'library': ['amplitude-ts/2.7.2' 'amplitude-ts/1.8.0']
# Frequency distribution:
#  library
# amplitude-ts/2.7.2    35535
# amplitude-ts/1.8.0     1942
# Name: count, dtype: int64
# Missing values: 0
#
# Summary Statistics:
#  count                  37477
# unique                     2
# top       amplitude-ts/2.7.2
# freq                   35535
# Name: library, dtype: object

# %% [markdown]
# 'amplitude-ts/2.7.2' refers to a specific version of the Amplitude JavaScript SDK for TypeScript. Amplitude is a popular product analytics platform used for tracking user behavior, events, and engagement within web and mobile applications.
#
# Here's a breakdown of what it likely refers to:
#
# amplitude-ts: This part indicates that it’s the TypeScript version of the Amplitude SDK. TypeScript is a superset of JavaScript that adds static types, making it easier to write and maintain large codebases with better tooling.
#
# 2.7.2: This is the version number of the SDK. In this case, it refers to version 2.7.2, which is one of the iterations or releases of the library.
#
# The SDK allows developers to send event data from their applications to Amplitude for analytics. In this case, version 2.7.2 would represent a specific release that might have certain features, improvements, or bug fixes compared to other versions

# %%
# 1. Unique Values
unique_device_types = df['device_type'].unique()
print("Unique values in 'device_type':", unique_device_types)

# 2. Frequency Distribution
device_type_freq = df['device_type'].value_counts()
print("\nFrequency distribution:\n", device_type_freq)

# 3. Missing Values
missing_device_types = df['device_type'].isnull().sum()
print("\nMissing values:", missing_device_types)

# 4. Summary Statistics
device_type_summary = df['device_type'].describe()
print("\nSummary Statistics:\n", device_type_summary)


# Plot the frequency distribution
plt.figure(figsize=(10, 6))
device_type_freq = df['device_type'].value_counts()
device_type_freq.plot(kind='bar', color='skyblue')

# Add title and labels
plt.title('Device Type Distribution', fontsize=14)
plt.xlabel('Device Type', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Unique values in 'device_type': ['Windows' 'Linux' nan 'Mac']
#
# Frequency distribution:
#  device_type
# Windows    30595
# Linux        413
# Mac           77
# Name: count, dtype: int64
#
# Missing values: 6392
#
# Summary Statistics:
#  count       31085
# unique          3
# top       Windows
# freq        30595
# Name: device_type, dtype: object

# %%
# 4. Summary statistics
device_id_summary = df['device_id'].describe()
print(f"\nSummary Statistics:\n{device_id_summary}")
# Out:
# Summary Statistics:
# count                                    37477
# unique                                     491
# top       6148e3ea-93e7-4138-aeee-fd40411fa3b8
# freq                                       768
# Name: device_id, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Check for missing values in the 'device_family' column
missing_values = df['device_family'].isnull().sum()
print(f"Missing values in 'device_family': {missing_values}")

# 2. Distribution of the 'device_family' column
device_family_counts = df['device_family'].value_counts()
print(f"Device Family Distribution:\n{device_family_counts}")

# 3. Plot the distribution of device families
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='device_family', order=device_family_counts.index)
plt.title('Distribution of Device Families')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 4. Show the top 10 most frequent device families
top_device_families = device_family_counts.head(10)
print(f"Top 10 Device Families:\n{top_device_families}")

# 5. Plot top 10 device families
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='device_family', order=top_device_families.index)
plt.title('Top 10 Device Families')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Missing values in 'device_family': 0
# Device Family Distribution:
# device_family
# Windows     30595
# Mac OS X     6367
# Linux         413
# Mac            77
# iOS            25
# Name: count, dtype: int64
# Top 10 Device Families:
# device_family
# Windows     30595
# Mac OS X     6367
# Linux         413
# Mac            77
# iOS            25
# Name: count, dtype: int64

# %%
country_counts = df['country'].value_counts()
print(country_counts)

# 3. Check for missing values
missing_values = df['country'].isnull().sum()
print(f"Missing values in 'country' column: {missing_values}")

# 4. Visualize the distribution of countries
plt.figure(figsize=(10, 6))
plt.xticks(rotation=90)
plt.title('Distribution of Countries in Dataset')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# 5. Check for unique country names
unique_countries = df['country'].unique()
print(f"Unique countries in the dataset: {unique_countries}")

unique_countries = df['country'].nunique()
print("Number of unique countries:", unique_countries)
# Out:
# country
# United States     28625
# India              7954
# Poland              534
# Canada              188
# United Kingdom       86
# Mexico               59
# France               19
# Denmark              12
# Name: count, dtype: int64
# Missing values in 'country' column: 0
# Unique countries in the dataset: ['United States' 'India' 'Poland' 'Canada' 'United Kingdom' 'France'
#  'Mexico' 'Denmark']
# Number of unique countries: 8

# %%
# 1. Check for missing values in the 'city' column
missing_values = df['city'].isnull().sum()
print(f'Missing values in city column: {missing_values}')

# 2. Drop rows with missing 'city' values
df_cleaned = df.dropna(subset=['city'])

# 3. Get the count of unique cities
unique_cities_count = df_cleaned['city'].nunique()
print(f'Number of unique cities: {unique_cities_count}')

# 4. Get the top 10 most frequent cities
top_cities = df_cleaned['city'].value_counts().head(10)
print(f'Top 10 most frequent cities:\n{top_cities}')

# 5. Plot the top 10 most frequent cities
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cities.index, y=top_cities.values, palette='viridis')
plt.title('Top 10 Most Frequent Cities')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# Missing values in city column: 274
# Number of unique cities: 139
# Top 10 most frequent cities:
# city
# Nashville     9662
# Mumbai        7954
# Chicago       1709
# New York      1348
# Greenville    1172
# Urbandale      680
# Atlanta        660
# Charlotte      466
# Wroclaw        455
# Miami          412
# Name: count, dtype: int64
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/3799731103.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities.index, y=top_cities.values, palette='viridis')

# %%
# 1. Check for missing values
print(f'Missing values in language column: {df["language"].isnull().sum()}')

# 2. Clean the data (remove rows with missing language values)
df_cleaned = df.dropna(subset=['language'])

# 3. Unique languages count and most frequent languages
print(f'Number of unique languages: {df_cleaned["language"].nunique()}')
top_languages = df_cleaned['language'].value_counts().head(10)
print(f'Top 10 most frequent languages:\n{top_languages}')

# 4. Plot top 10 most frequent languages
plt.figure(figsize=(10, 6))
sns.barplot(x=top_languages.index, y=top_languages.values, palette='viridis')
plt.title('Top 10 Most Frequent Languages')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 5. Distribution of events by language
plt.figure(figsize=(12, 6))
sns.countplot(x='language', data=df_cleaned, palette='magma')
plt.title('Event Count by Language')
plt.xlabel('Language')
plt.ylabel('Number of Events')
plt.xticks(rotation=90)
plt.show()
# Out:
# Missing values in language column: 0
# Number of unique languages: 3
# Top 10 most frequent languages:
# language
# English    37197
# Polish       221
# Spanish       59
# Name: count, dtype: int64
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/2857037985.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_languages.index, y=top_languages.values, palette='viridis')
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/2857037985.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='language', data=df_cleaned, palette='magma')

# %%
# 1. Check for missing values in the dma column
print(f'Missing values in dma column: {df["dma"].isnull().sum()}')

# 2. Clean the data (remove rows with missing dma values)
df_cleaned = df.dropna(subset=['dma'])

# 3. Unique DMA count and most frequent DMAs
print(f'Number of unique DMAs: {df_cleaned["dma"].nunique()}')
top_dma = df_cleaned['dma'].value_counts().head(10)
print(f'Top 10 most frequent DMAs:\n{top_dma}')

# 4. Plot top 10 most frequent DMAs
plt.figure(figsize=(10, 6))
sns.barplot(x=top_dma.index, y=top_dma.values, palette='viridis')
plt.title('Top 10 Most Frequent DMAs')
plt.xlabel('DMA')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 5. Distribution of events by DMA
plt.figure(figsize=(12, 6))
sns.countplot(x='dma', data=df_cleaned, palette='magma')
plt.title('Event Count by DMA')
plt.xlabel('DMA')
plt.ylabel('Number of Events')
plt.xticks(rotation=90)
plt.show()
# Out:
# Missing values in dma column: 9126
# Number of unique DMAs: 53
# Top 10 most frequent DMAs:
# dma
# Nashville, TN                         9667
# Chicago, IL                           1893
# Greenville-Spartanburg, SC            1783
# New York, NY                          1742
# Des Moines-Ames, IA                   1673
# Atlanta, GA                           1464
# Cleveland-Akron (Canton), OH          1028
# Washington, DC (Hagerstown, MD)        665
# Charlotte, NC                          603
# San Francisco-Oakland-San Jose, CA     591
# Name: count, dtype: int64
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/2153832354.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_dma.index, y=top_dma.values, palette='viridis')
# /var/folders/c0/qh7w74pn7x5f5q81vn0wf7480000gn/T/ipykernel_29617/2153832354.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='dma', data=df_cleaned, palette='magma')
